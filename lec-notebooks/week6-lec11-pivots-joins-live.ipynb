# %%
from datascience import *
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

# %% [markdown]
# ## Lists

# %%
simple_list = ['hello', 7, 3.14, True]
simple_list 
# you can different data types within a single list
# string, int, float, boolean
# Out:
# ['hello', 7, 3.14, True]

# %%
my_array = make_array('hello', 7, 3.14, True)
my_array # arrays want all elements to be of the same data type
# all integers, all floats, all strings, etc.
# Out:
# array(['hello', '7', '3.14', 'True'], dtype='<U32')

# %%
my_array = make_array(1, 2, 3)

crowded_list = [my_array, 'what is going on', -10]
crowded_list[0] # accessing the first element in my list, position 0
crowded_list[1]# accessing the second element in my list, position 1
crowded_list[2] # access last element, in position 2
crowded_list[-1]# access last element, in position -1
crowded_list[-4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_101/575388213.py in <cell line: 8>()
#       6 crowded_list[2] # access last element, in position 2
#       7 crowded_list[-1]# access last element, in position -1
# ----> 8 crowded_list[-4]
#
# IndexError: list index out of range

# %%
Table().with_columns('Numbers', [1, 2, 3])
# Out:
# Numbers
# 1
# 2
# 3

# %%
drinks = Table(['Drink', 'Cafe', 'Price']) # column headings, using a list
drinks
# Out:
# Drink | Cafe | Price

# %%
drinks = drinks.with_rows([
    ['Milk Tea', 'Asha', 5.50],
    ['Espresso', 'Strada',  1.75],
    ['Latte',    'Strada',  3.25],
    ['Espresso', "FSM",   2]
])
drinks
# try adding a new row, 
# boba drink from Hochaya $5.00
# Out:
# Drink    | Cafe   | Price
# Milk Tea | Asha   | 5.5
# Espresso | Strada | 1.75
# Latte    | Strada | 3.25
# Espresso | FSM    | 2

# %% [markdown]
# ## Challenge Question ##

# %%
sky = Table.read_table('data/skyscrapers_v2.csv')
sky = (sky.with_column('age', 2022 - sky.column('completed'))
          .drop('completed'))
sky.show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>name</th> <th>material</th> <th>city</th> <th>height</th> <th>age</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>One World Trade Center                                      </td> <td>mixed/composite</td> <td>New York City    </td> <td>541.3 </td> <td>8   </td>
#         </tr>
#         <tr>
#             <td>Willis Tower                                                </td> <td>steel          </td> <td>Chicago          </td> <td>442.14</td> <td>48  </td>
#         </tr>
#         <tr>
#             <td>432 Park Avenue                                             </td> <td>concrete       </td> <td>New York City    </td> <td>425.5 </td> <td>7   </td>
#         </tr>
#         <tr>
#             <td>Trump International Hotel & Tower                           </td> <td>concrete       </td> <td>Chicago          </td> <td>423.22</td> <td>13  </td>
#         </tr>
#         <tr>
#             <td>Empire State Building                                       </td> <td>steel          </td> <td>New York City    </td> <td>381   </td> <td>91  </td>
#         </tr>
#         <tr>
#             <td>Bank of America Tower                                       </td> <td>mixed/composite</td> <td>New York City    </td> <td>365.8 </td> <td>13  </td>
#         </tr>
#         <tr>
#             <td>Stratosphere Tower                                          </td> <td>concrete       </td> <td>Las Vegas        </td> <td>350.22</td> <td>26  </td>
#         </tr>
#         <tr>
#             <td>Aon Center                                                  </td> <td>steel          </td> <td>Chicago          </td> <td>346.26</td> <td>49  </td>
#         </tr>
#         <tr>
#             <td>John Hancock Center                                         </td> <td>steel          </td> <td>Chicago          </td> <td>343.69</td> <td>53  </td>
#         </tr>
#         <tr>
#             <td>Chrysler Building                                           </td> <td>steel          </td> <td>New York City    </td> <td>318.9 </td> <td>92  </td>
#         </tr>
#         <tr>
#             <td>New York Times Tower                                        </td> <td>steel          </td> <td>New York City    </td> <td>318.77</td> <td>15  </td>
#         </tr>
#         <tr>
#             <td>Bank of America Plaza                                       </td> <td>mixed/composite</td> <td>Atlanta          </td> <td>311.8 </td> <td>30  </td>
#         </tr>
#         <tr>
#             <td>U.S. Bank Tower                                             </td> <td>steel          </td> <td>Los Angeles      </td> <td>310.29</td> <td>32  </td>
#         </tr>
#         <tr>
#             <td>The Franklin - North Tower                                  </td> <td>mixed/composite</td> <td>Chicago          </td> <td>306.94</td> <td>33  </td>
#         </tr>
#         <tr>
#             <td>One57                                                       </td> <td>mixed/composite</td> <td>New York City    </td> <td>306.07</td> <td>8   </td>
#         </tr>
#         <tr>
#             <td>JPMorgan Chase Tower                                        </td> <td>mixed/composite</td> <td>Houston          </td> <td>305.41</td> <td>40  </td>
#         </tr>
#         <tr>
#             <td>Two Prudential Plaza                                        </td> <td>concrete       </td> <td>Chicago          </td> <td>303.28</td> <td>32  </td>
#         </tr>
#         <tr>
#             <td>Wells Fargo Plaza                                           </td> <td>steel          </td> <td>Houston          </td> <td>302.37</td> <td>39  </td>
#         </tr>
#         <tr>
#             <td>4 World Trade Center                                        </td> <td>mixed/composite</td> <td>New York City    </td> <td>297.73</td> <td>8   </td>
#         </tr>
#         <tr>
#             <td>Comcast Center                                              </td> <td>mixed/composite</td> <td>Philadelphia     </td> <td>296.73</td> <td>14  </td>
#         </tr>
#         <tr>
#             <td>311 South Wacker Drive                                      </td> <td>concrete       </td> <td>Chicago          </td> <td>292.92</td> <td>32  </td>
#         </tr>
#         <tr>
#             <td>70 Pine                                                     </td> <td>steel          </td> <td>New York City    </td> <td>290.17</td> <td>90  </td>
#         </tr>
#         <tr>
#             <td>Key Tower                                                   </td> <td>mixed/composite</td> <td>Cleveland        </td> <td>288.65</td> <td>31  </td>
#         </tr>
#         <tr>
#             <td>One Liberty Place                                           </td> <td>steel          </td> <td>Philadelphia     </td> <td>288.04</td> <td>35  </td>
#         </tr>
#         <tr>
#             <td>Columbia Center                                             </td> <td>mixed/composite</td> <td>Seattle          </td> <td>284.38</td> <td>38  </td>
#         </tr>
#         <tr>
#             <td>The Trump Building                                          </td> <td>steel          </td> <td>New York City    </td> <td>282.55</td> <td>92  </td>
#         </tr>
#         <tr>
#             <td>Bank of America Plaza                                       </td> <td>mixed/composite</td> <td>Dallas           </td> <td>280.72</td> <td>37  </td>
#         </tr>
#         <tr>
#             <td>Citigroup Center                                            </td> <td>steel          </td> <td>New York City    </td> <td>278.9 </td> <td>45  </td>
#         </tr>
#         <tr>
#             <td>Williams Tower                                              </td> <td>steel          </td> <td>Houston          </td> <td>274.63</td> <td>40  </td>
#         </tr>
#         <tr>
#             <td>Renaissance Tower                                           </td> <td>steel          </td> <td>Dallas           </td> <td>270.06</td> <td>36  </td>
#         </tr>
#         <tr>
#             <td>Bank of America Corporate Center                            </td> <td>concrete       </td> <td>Charlotte        </td> <td>265.48</td> <td>30  </td>
#         </tr>
#         <tr>
#             <td>Eight Spruce Street                                         </td> <td>concrete       </td> <td>New York City    </td> <td>265.18</td> <td>11  </td>
#         </tr>
#         <tr>
#             <td>900 North Michigan Avenue                                   </td> <td>mixed/composite</td> <td>Chicago          </td> <td>265   </td> <td>33  </td>
#         </tr>
#         <tr>
#             <td>SunTrust Plaza                                              </td> <td>concrete       </td> <td>Atlanta          </td> <td>264.25</td> <td>30  </td>
#         </tr>
#         <tr>
#             <td>Trump World Tower                                           </td> <td>concrete       </td> <td>New York City    </td> <td>262.44</td> <td>21  </td>
#         </tr>
#         <tr>
#             <td>Water Tower Place                                           </td> <td>concrete       </td> <td>Chicago          </td> <td>261.88</td> <td>46  </td>
#         </tr>
#         <tr>
#             <td>Aqua                                                        </td> <td>concrete       </td> <td>Chicago          </td> <td>261.75</td> <td>13  </td>
#         </tr>
#         <tr>
#             <td>Aon Center                                                  </td> <td>steel          </td> <td>Los Angeles      </td> <td>261.52</td> <td>48  </td>
#         </tr>
#         <tr>
#             <td>Transamerica Pyramid                                        </td> <td>mixed/composite</td> <td>San Francisco    </td> <td>260   </td> <td>50  </td>
#         </tr>
#         <tr>
#             <td>Comcast Building                                            </td> <td>steel          </td> <td>New York City    </td> <td>259.08</td> <td>89  </td>
#         </tr>
#         <tr>
#             <td>Chase Tower                                                 </td> <td>steel          </td> <td>Chicago          </td> <td>259.08</td> <td>53  <

# %%
# 1. For each city, what’s the tallest building for each material?
sky.select('name','material','height').group('material', max)




# the tallest building for concrete
# tallest building for mixed/composite
# tallest building for steel

# can you provide all three information above in one table?
# Out:
# material        | name max                 | height max
# concrete        | theWit Hotel             | 425.5
# mixed/composite | Westin Bonaventure Hotel | 541.3
# steel           | Wyndham New Yorker Hotel | 442.14

# %%
'ab'< 'b'
# Out:
# True

# %%
sky.select('material', 'city', 'height').group(['city', 'material'], max)

# %%
# 2. For each city, what’s the height difference between the tallest 
#    steel building and the tallest concrete building?






# oldest building for each material, in each city
# atlanta - oldest building for concrete, composite, steel

# %% [markdown]
# Don't read ahead until you try the challenge questions yourself first!

# %% [markdown]
# ### Take-home question: try it here!

# %%
# Generate a table of the names of the oldest buildings for each 
# material for each city: (requires join)
sky_pivot = sky.pivot("material","city","age",max)
sky_pivot.join()
# generate a table of the average ages of buildings, by material, for each city:
# Out:
# city       | concrete | mixed/composite | steel
# Atlanta    | 46       | 35              | 125
# Austin     | 38       | 0               | 85
# Baltimore  | 55       | 0               | 111
# Boston     | 51       | 30              | 107
# Charlotte  | 30       | 20              | 98
# Chicago    | 93       | 96              | 134
# Cincinnati | 68       | 11              | 109
# Cleveland  | 42       | 64              | 98
# Columbus   | 59       | 0               | 95
# Dallas     | 44       | 37              | 94
# ... (25 rows omitted)

# %% [markdown]
# ## Joins ##

# %%
drinks

# %%
discounts = Table().with_columns(
    'Coupon % off', make_array(10, 25, 5),
    'Location', make_array('Asha', 'Strada', 'Asha')
)
discounts

# %%
combined = drinks.join('Cafe', discounts, 'Location')
combined

# %%
discounted_frac = 1 - combined.column('Coupon % off') / 100
combined.with_column(
    'Discounted Price', 
    combined.column('Price') * discounted_frac
)

# %%
drinks.join('Cafe', drinks, 'Cafe')
